# %%
import sys, os
import pandas as pd
import numpy as np
from numba import jit
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import signal
import timeit
import math
from datetime import datetime
import requests
import time
import bs4

# import mysql.connector
from prothomAloClass import *
from somoyNewsClass import *
from BanglaTribuneClass import *
from BdNewsClass import *
from DailyStarClass import *

class CrawlerUtils:    
    def save_article_to_db(self, article, hash):
        '''
        Implement
        '''
    def get_article_hash(self, article):
        return hash(article['article_title'] + article['base_url'])

    def has_article_with_hash(self, _hash):
        '''
        '''
        return False

class PerpetualNewsCrawler:
    def __init__(self, crawlers, crawl_interval):
        self.crawlers = crawlers
        self.crawl_interval = crawl_interval
        self.stop_signalled = False

    def save_articles(self, source_info, articles):
        '''
        Implement codes for saving articles in DB
        '''
        for article in articles['articles']:
            _hash = CrawlerUtils.get_article_hash(article)
            if CrawlerUtils.has_article_with_hash(_hash):
                CrawlerUtils.save_article_to_db(article, _hash)

        if source_info is not None and articles is not None:
            print('crawled ', articles['article_count'], ' articles from ', source_info['source_name'])
  
    def signal_to_stop(self):
        self.stop_signalled = True

    def resume_crawl(self):
        self.stop_signalled = False
        self.crawl()
    
    def crawl(self):
        while True:
            for crawler in self.crawlers:
                source_info = crawler.get_source_info()
                articles_info = crawler.fetch_all_articles()
                #print(crawler.base_url)
                #self.save_articles(source_info, articles_info)
            if self.stop_signalled:
                break
            else:
                time.sleep(self.crawl_interval)
        
prothomAlo_crawler = prothomAloCrawler()
dailyStar_crawler = dailyStarCrawler()
somoyNews_crawler = somoyNewsCrawler()
bdNews_crawler = bdNewsCrawler()
banglaTribune_crawler = banglaTribuneCrawler()
#jugantor_crawler = jugantorCrawler()
crawlers = [prothomAlo_crawler, dailyStar_crawler, bdNews_crawler, banglaTribune_crawler, somoyNews_crawler]

PerpetualNewsCrawler = PerpetualNewsCrawler(crawlers, 3600)
PerpetualNewsCrawler.crawl()


# PerpetualNewsCrawler.signal_to_stop()
# Out:
# DS-start
# 1
# গণস্বাস্থ্য কেন্দ্র কিটের কার্যকারিতা নিরূপণে বিনা মূল্যে ২০০ রোগীর করোনা পরীক্ষা করবে
# 2
# গণস্বাস্থ্য কেন্দ্র কিটের কার্যকারিতা নিরূপণে বিনা মূল্যে ২০০ রোগীর করোনা পরীক্ষা করবে
# 3
# ঢাকায় খোলা থাকবে যেসব দোকান ও শপিংমল
# 4
# ঢাকায় খোলা থাকবে যেসব দোকান ও শপিংমল
# 5
# করোনায় দেশে আরও ১৪ জনের মৃত্যু, নতুন শনাক্ত ৮৮৭
# 6
# করোনায় দেশে আরও ১৪ জনের মৃত্যু, নতুন শনাক্ত ৮৮৭
# 7
# রডের বদলে বাঁশ দিয়ে স্কুলের ভবন নির্মাণ
# 8
# রডের বদলে বাঁশ দিয়ে স্কুলের ভবন নির্মাণ
# 9
# করোনা রোগীর বাড়িতে পুলিশের ঈদ উপহার
# 10
# করোনা রোগীর বাড়িতে পুলিশের ঈদ উপহার
# 11
# রাঙ্গামাটিতে করোনা আক্রান্ত ২ জনের দ্বিতীয় পরীক্ষার ফল নেগেটিভ
# 12
# রাঙ্গামাটিতে করোনা আক্রান্ত ২ জনের দ্বিতীয় পরীক্ষার ফল নেগেটিভ
# 13
# ধামরাইয়ে হত্যার অভিযোগে স্ত্রী-ছেলে গ্রেপ্তার
# 14
# ধামরাইয়ে হত্যার অভিযোগে স্ত্রী-ছেলে গ্রেপ্তার
# 15
# লি লিগায় মাঠে থুতু ফেললেই হলুদ কার্ড
# 16
# লি লিগায় মাঠে থুতু ফেললেই হলুদ কার্ড
# 17
# নারায়ণগঞ্জে বকেয়া বেতনের দাবিতে পোশাকশ্রমিকদের বিক্ষোভ
# 18
# নারায়ণগঞ্জে বকেয়া বেতনের দাবিতে পোশাকশ্রমিকদের বিক্ষোভ
# 19
# মা দিবসে মায়েদের উৎসর্গ করে ফকির আলমগীরের ২ গান
# 20
# মা দিবসে মায়েদের উৎসর্গ করে ফকির আলমগীরের ২ গান
# 21
# চির শয়ানে ‘গ্যাং লিডার’-অভিনেতা রানা হামিদ
# 22
# চির শয়ানে ‘গ্যাং লিডার’-অভিনেতা রানা হামিদ
# 23
# ‘নিজের কাছে মহামূল্যবান দুটি বস্তু করোনা আক্রান্তদের উৎসর্গ করেছি’
# 24
# ‘নিজের কাছে মহামূল্যবান দুটি বস্তু করোনা আক্রান্তদের উৎসর্গ করেছি’
# 25
# করোনাভাইরাস: করণীয় কী? ডাক্তার আবদুল্লাহর পরামর্শ
# 26
# করোনাভাইরাস: করণীয় কী? ডাক্তার আবদুল্লাহর পরামর্শ
# 27
# যুক্তরাষ্ট্রে করোনাভাইরাস গবেষককে হত্যার পর আত্মহত্যা
# 28
# কার্টুনিস্ট কিশোর, লেখক মুশতাক গ্রেপ্তার
# 29
# রাবির সহযোগী অধ্যাপক মাহবুবুর রহমান মারা গেছেন
# 30
# দেশে প্রথম রেমডেসিভির উৎপাদন করল এসকেএফ
# 31
# চলে গেলেন জাবি অধ্যাপক নিসার আহমেদ
# 32
# ঈদের ছুটিতে সরকারি চাকরিজীবীরা কর্মস্থল ছাড়তে পারবে না
# 33
# ‘সরকারি অফিস-আদালত সীমিত আকারে চালু করে দিচ্ছি, যাতে মানুষের কষ্ট না হয়’
# 34
# ‘কাজলের হাতের হাতকড়া তো দেখা যাচ্ছে, আপনার হাতেরটা দেখতে পান?’
# 35
# দেশে ফেরার দাবিতে রামপালে ভারতীয় শ্রমিকদের বিক্ষোভ
# 36
# নড়াইলে করোনার উপসর্গ নিয়ে একজনের মৃত্যু
# 37
# নড়াইলে করোনার উপসর্গ নিয়ে একজনের মৃত্যু
# 38
# মে মাসের তৃতীয় বা শেষ সপ্তাহে চরম পর্যায়ে যেতে পারে করোনা সংক্রমণ
# 39
# মে মাসের তৃতীয় বা শেষ সপ্তাহে চরম পর্যায়ে যেতে পারে করোনা সংক্রমণ
# 40
# করোনা উপসর্গ নিয়ে কচুয়ায় এক ব্যক্তির মৃত্যু
# 41
# করোনা উপসর্গ নিয়ে কচুয়ায় এক ব্যক্তির মৃত্যু
# 42
# রংপুরে করোনা শনাক্ত ১২৮ জনের, ১৭ শর্তে খুলছে বিপণিবিতান
# 43
# রংপুরে করোনা শনাক্ত ১২৮ জনের, ১৭ শর্তে খুলছে বিপণিবিতান
# 44
# সেশনজট কাটাতে ছুটি কমানোর পরিকল্পনা ঢাবির
# 45
# সেশনজট কাটাতে ছুটি কমানোর পরিকল্পনা ঢাবির
# 46
# চীনের গলার কাঁটা যুক্তরাষ্ট্রের সঙ্গে ২০০ বিলিয়ন ডলারের বাণিজ্য চুক্তি
# 47
# চীনের গলার কাঁটা যুক্তরাষ্ট্রের সঙ্গে ২০০ বিলিয়ন ডলারের বাণিজ্য চুক্তি
# 48
# যুক্তরাজ্যে আটকেপড়া বাংলাদেশি শিক্ষার্থীরা দেশে ফিরছেন আগামীকাল
# 49
# যুক্তরাজ্যে আটকেপড়া বাংলাদেশি শিক্ষার্থীরা দেশে ফিরছেন আগামীকাল
# 50
# পুলিশ পরিচয়ে চাঁদা দাবি, ৩ প্রতারককে ধরিয়ে দিলো ব্যবসায়ীরা
# 51
# পুলিশ পরিচয়ে চাঁদা দাবি, ৩ প্রতারককে ধরিয়ে দিলো ব্যবসায়ীরা
# 52
# সংসদ সদস্যের আইসিটি মামলায় কারাগারে ছাত্রলীগ কর্মী
# 53
# সংসদ সদস্যের আইসিটি মামলায় কারাগারে ছাত্রলীগ কর্মী
# 54
# ঝিনাইদহে ট্রাকচাপায় ইউপি সদস্য নিহত
# 55
# ঝিনাইদহে ট্রাকচাপায় ইউপি সদস্য নিহত
# 56
# মৃত্যু ২ লাখ ৭৯ হাজার, আক্রান্ত ৪০ লাখ ছাড়াল
# 57
# মৃত্যু ২ লাখ ৭৯ হাজার, আক্রান্ত ৪০ লাখ ছাড়াল
# 58
# করোনাভাইরাস মোকাবিলায় একসঙ্গে চীন-রাশিয়া
# 59
# করোনাভাইরাস মোকাবিলায় একসঙ্গে চীন-রাশিয়া
# 60
# স্বামীর নির্যাতনে অন্তঃসত্ত্বা নারীর মৃত্যু
# 61
# স্বামীর নির্যাতনে অন্তঃসত্ত্বা নারীর মৃত্যু
# Problem in extraction...
# DS-end
# BN-start
# BN-end
# BT-start
# BT-end
# SN-start
# DA-end
